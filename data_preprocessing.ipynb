# %% [markdown]
# DATA PREPROCESSING
#
# 1. Import the necessary libraries
#
# 2. Load the dataset
# ```python
# df = pd.read_csv("ago/USA_Housing.csv")
# print(df.head())
# ```
#
# View the data
# ```python
# df.info()
# df.dtypes.value_counts()
# df.isnull().sum()
# df.duplicated().sum()
# ```
#
# 3. Statistical Analysis
# ```python
# df.desrcibe(include='all')
# ```
#
# Create cat col and num col
# Clean the data(**look at data_cleaning.ipynb**)
# ```python
# # New df with only numeric features
# numeric_df = df.select_dtypes(include=[int, float])
# ```
#
# 4.  Check the outliers
#
# 5. Drop the ourliers
#
# 6. Correlation
# 1 indicates high positive corr, if one inc the other inc
# -1 shows perfect negative corr, if one inc, the other dec
# 0 shows weak corr, one cannnot be used to predict another
#
# 7. Separate independet features X and target variables y
# 8. Standardization and Normalization

# %%
# Data Preprocessing

# 1. Import the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# 2. Load the dataset
df = pd.read_csv("ago/USA_Housing.csv")
print(df.head())
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
# Check the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# Check the data types
df.dtypes.value_counts()
# Out:
# float64    6
# object     1
# Name: count, dtype: int64

# %%
# Check the null values
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# 3. Statistical Analysis
df.describe(include='all')
# Out:
#         Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count        5000.000000          5000.000000                5000.000000
# unique               NaN                  NaN                        NaN
# top                  NaN                  NaN                        NaN
# freq                 NaN                  NaN                        NaN
# mean        68583.108984             5.977222                   6.987792
# std         10657.991214             0.991456                   1.005833
# min         17796.631190             2.644304                   3.236194
# 25%         61480.562388             5.322283                   6.299250
# 50%         68804.286404             5.970429                   7.002902
# 75%         75783.338666             6.650808                   7.665871
# max        107701.748378             9.519088                  10.759588
#
#         Avg. Area Number of Bedrooms  Area Population         Price  \
# count                    5000.000000      5000.000000  5.000000e+03
# unique                           NaN              NaN           NaN
# top                              NaN              NaN           NaN
# freq                             NaN              NaN           NaN
# mean                        3.981330     36163.516039  1.232073e+06
# std                         1.234137      9925.650114  3.531176e+05
# min                         2.000000       172.610686  1.593866e+04
# 25%                         3.140000     29403.928702  9.975771e+05
# 50%                         4.050000     36199.406689  1.232669e+06
# 75%                         4.490000     42861.290769  1.471210e+06
# max                         6.500000     69621.713378  2.469066e+06
#
#                                                   Address
# count                                                5000
# unique                                               5000
# top     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Select only numeric columns (by default, includes int64 and float64)
numeric_df = df.select_dtypes(include=[int, float])
numeric_df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
# Check for outliers
# Determine number of columns and set dynamic number of subplots
num_cols = len(numeric_df.columns)

# Create a subplot with num_cols rows and 1 column
fig, axs = plt.subplots(num_cols, 1, dpi=95, figsize=(6,13))

# If there's only one column, wrap axs in a list
if num_cols == 1:
    axs = [axs]

# Loop through the columns and create box plots
i = 0
for col in numeric_df:
    axs[i].boxplot(df[col], vert=False)  # Create horizontal box plot
    axs[i].set_ylabel(col)               # Label each plot with column name
    i += 1

plt.show()

# %%
# Drop Outliers

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(df['Avg. Area Income'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = df[(df['Avg. Area Income'] >= lower_bound) & (df['Avg. Area Income'] <= upper_bound)]
# Print the number of outliers removed
print(f"Original dataset size: {len(df)}")
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(clean_data['Avg. Area House Age'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['Avg. Area House Age'] >= lower_bound) & (clean_data['Avg. Area House Age'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(clean_data['Avg. Area Number of Rooms'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['Avg. Area Number of Rooms'] >= lower_bound) & (clean_data['Avg. Area Number of Rooms'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(clean_data['Avg. Area Number of Bedrooms'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['Avg. Area Number of Bedrooms'] >= lower_bound) & (clean_data['Avg. Area Number of Bedrooms'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(clean_data['Area Population'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['Area Population'] >= lower_bound) & (clean_data['Area Population'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")

# Identify the 1st (Q1) and 3rd (Q3) quartiles
q1, q3 = np.percentile(clean_data['Price'], [25, 75])
# Calculate the Interquartile Range (IQR)
iqr = q3 - q1
# Calculate the lower and upper bounds for detecting outliers
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
# Drop the outliers from the DataFrame
clean_data = clean_data[(clean_data['Price'] >= lower_bound) & (clean_data['Price'] <= upper_bound)]
# Print the number of outliers removed
print(f"Clean dataset size: {len(clean_data)}")
# Out:
# Original dataset size: 5000
# Clean dataset size: 4968
# Clean dataset size: 4943
# Clean dataset size: 4918
# Clean dataset size: 4918
# Clean dataset size: 4889
# Clean dataset size: 4856

# %%
# Select only numeric columns (by default, includes int64 and float64)
numeric_df_clean = clean_data.select_dtypes(include=[int, float])

# Boxplot without outliers
num_cols = len(numeric_df_clean.columns)
fig, axs = plt.subplots(num_cols, 1, dpi=95, figsize=(6,13))

# Loop through the columns and create box plots
i = 0
for col in numeric_df_clean:
    axs[i].boxplot(numeric_df_clean[col], vert=False)  # Create horizontal box plot
    axs[i].set_ylabel(col)               # Label each plot with column name
    i += 1

plt.show()

#notice the outliers have greatly reduced

# %%
# Correlation
corr = numeric_df_clean.corr()
 
plt.figure(dpi=130, figsize=(5,2))
sns.heatmap(corr, annot=True, fmt='.2f', cbar=True, linewidths=0.5)
plt.show()

# %%
corr['Avg. Area House Age'].sort_values(ascending = False)
# Out:
# Avg. Area House Age             1.000000
# Price                           0.439235
# Avg. Area Number of Bedrooms   -0.001091
# Avg. Area Number of Rooms      -0.019152
# Avg. Area Income               -0.025542
# Area Population                -0.026308
# Name: Avg. Area House Age, dtype: float64

# %%
# Separate X and y
# separate array into input and output components
X_train = clean_data.drop(columns =['Price'])
y_train = df.Price

X_train_numeric = numeric_df_clean.drop(columns=['Price'])

# %%
# Normalization
# initialising the MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# learning the statistical parameters for each of the data and transforming
minmax_X_train_num = scaler.fit_transform(X_train_numeric)
minmax_X_train_num[:5]
# Out:
# array([[0.69165074, 0.44162376, 0.50165733, 0.46444444, 0.25429952],
#        [0.68644077, 0.50201725, 0.4502983 , 0.24222222, 0.57381341],
#        [0.37116387, 0.47616251, 0.77906192, 0.69555556, 0.51227322],
#        [0.40729068, 0.72569845, 0.23921205, 0.28      , 0.46417829],
#        [0.34825968, 0.32041599, 0.65483005, 0.49555556, 0.31539832]])

# %%
# Standardization
scaler = StandardScaler().fit(X_train_numeric)
std_scaledX_train_num = scaler.transform(X_train_numeric)
std_scaledX_train_num[:5]
# Out:
# array([[ 1.06268604, -0.30482511,  0.02283475,  0.0855128 , -1.35376874],
#        [ 1.03380094,  0.02678697, -0.26000937, -0.72435215,  0.41960349],
#        [-0.71415627, -0.11517771,  1.55055551,  0.92777234,  0.07804195],
#        [-0.51386214,  1.25498872, -1.4225022 , -0.5866751 , -0.18889548],
#        [-0.84114161, -0.97035973,  0.86638652,  0.19889389, -1.01465702]])
